# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list("adlsconnection")

# %%
configs = {
  "fs.azure.account.auth.type": "OAuth",
  "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
  "fs.azure.account.oauth2.client.id": dbutils.secrets.get(scope="adlsconnection", key="clientid"),
  "fs.azure.account.oauth2.client.secret": dbutils.secrets.get(scope="adlsconnection", key="secret"),
  "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/b9b0d8ab-2a0a-4453-a4f5-34f2ed2382fd/oauth2/token"
}

dbutils.fs.mount(
  source = "abfss://input@adlsacntvishalkanaka.dfs.core.windows.net/",
  mount_point = "/mnt/input",
  extra_configs=configs)

# %%
transactions=spark.read.format('csv').options(inferschema=True).load('/mnt/input/transactions.csv')

# %%
display(transactions)

# %%
dbutils.fs.unmount("/mnt/input")
